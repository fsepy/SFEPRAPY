# %%
# %matplotlib inline

import io
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import interpolate
from distribution_auto_fit import best_fit_distribution
import scipy.stats as st

sns.set_style('ticks')

# %%
data_csv = pd.read_csv('samples_car_park_qfd_andersonbell.csv', header=0, dtype=float)
cdf = data_csv['cdf']
q = data_csv['qfd']

cdf_func = interpolate.interp1d(cdf, q, kind='linear')

n_sample = 10000
samples_y = np.random.uniform(size=n_sample)
samples = np.sort(cdf_func(samples_y))

y, x = np.histogram(samples, bins=100, density=True)
x = (x + np.roll(x, -1))[:-1] / 2.0

print("Statistical Data")
fig, (ax1, ax2) = plt.subplots(nrows=1,ncols=2,constrained_layout=True,figsize=(3.94*2, 2.76));
ax1.plot(x, y);
ax1.set_xlabel('Fire load [kW/sq.m]');
ax1.set_ylabel('PDF');
ax2.plot(samples, np.linspace(0,1,len(samples)));
ax2.set_xlabel('Fire load [kW/sq.m]');
ax2.set_ylabel('CDF');
# Out:
# Statistical Data

# %%
dist_name, params = best_fit_distribution(samples)
print("Best: {}, Params: {}".format(dist_name, str(params)))
# Out:
# Distribution                  Loss (Residual sum of squares)
# alpha                         0.00835 - (48.38290376952466, -88.87251625972675, 16483.320695810282)
# chi                           0.00834 - (42.21804956460949, 187.3611282541308, 9.993376635292098)
# exponnorm                     0.00811 - (0.02936281727473373, 251.74007080436274, 6.99578173575202)
# exponweib                     0.44195 - (4.063971817101714, 0.2290449173254645, 226.41608025045866, 0.41330829152608967)
# exponpow                      0.47921 - (0.11974023934369535, 226.41608025045866, 1.7139570714388963)
# gumbel_r                      0.01675 - (248.42026683758985, 7.058300391422408)
# gumbel_l                      0.01401 - (255.41614228102569, 6.701654024478136)
# logistic                      0.00994 - (252.0022356495171, 4.037026956273637)
# lognorm                       0.00815 - (0.009194990788372003, -508.46765572636696, 760.3944302508335)
# maxwell                       0.02987 - (226.40654562400093, 15.288627322551708)
# norm                          0.00811 - (251.94552195282247, 6.998940460111877)
# uniform                       0.08666 - (226.4160802504587, 48.32383107679837)
# Best: norm, Params: (251.94552195282247, 6.998940460111877)

# %%
print("Fitted Data")
y = np.linspace(0,1,1000)
x = st.norm.ppf(y, *(251.90611757771737, 7.015945381175767))
fig3, ax3 = plt.subplots(figsize=(3.94, 2.76));
ax3.plot(x, y)
